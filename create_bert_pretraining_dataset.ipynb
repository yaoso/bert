# %%
import os
from pathlib import Path
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm
from create_pretraining_data import process
# Imports the Google Cloud client library
from google.cloud import storage
# Out:
# 2022-07-01 16:09:50.013135: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:50.013174: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# bucket = client.create_bucket('test-name')

# %%
# # Instantiates a client
# client = storage.Client()

# bucket = client.get_bucket('us-central1-f-wukong')

# new_blob = bucket.blob('WuDaoCorpus/bert_pretrainint/{}.parquet')
# new_blob.upload_from_filename(filename='/home/lj/bert/part-2021015155.parquet')

# os.remove("./a.txtd")

# %%
path = Path('/home/lj/WuDaoCorpus2.0_small_20G_text/')
files = [str(i) for i in path.glob("*.txt")]

# %%
len(files)
# Out:
# 366

# %%
files[:3]
# Out:
# ['/home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022489.txt',
#  '/home/lj/WuDaoCorpus2.0_small_20G_text/part-2021016914.txt',
#  '/home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021957.txt']

# %%
outputs = [i.split('/')[-1][:-4] for i in files]

# %%
outputs[:3]
# Out:
# ['part-2021022489', 'part-2021016914', 'part-2021021957']

# %%
Parallel(80)(delayed(process)(input_file, output_file, '/home/lj/vocab.txt') 
             for input_file, output_file in tqdm(zip(files, outputs)))
# Out:
# 80it [00:01, 65.57it/s]2022-07-01 16:09:53.743983: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.750369: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.750372: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.750369: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.750369: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.759303: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.759301: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.759299: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.790157: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.793083: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795727: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795727: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795732: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795732: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795778: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795788: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795791: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795794: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795828: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795840: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795840: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795843: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795841: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795872: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795907: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795916: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795919: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795926: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795928: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.795934: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.796031: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.796030: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.796056: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.797819: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799616: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799630: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799638: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799698: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799793: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799795: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799870: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.799903: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800021: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800046: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800053: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800079: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800703: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800849: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.800893: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.816886: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.831529: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.831559: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.845687: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.923421: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.965464: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.965464: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.969234: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.969741: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:53.992092: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.007967: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.086381: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.087538: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.091347: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.091344: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.094683: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.095640: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.115755: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.140808: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.162033: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.201095: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.293087: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.340024: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.340023: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.344158: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.464844: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.466143: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.494940: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.516693: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.596385: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# 2022-07-01 16:09:54.608533: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/lib
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.419170    9690 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.421783    9620 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.422605    9701 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662995.422605    9693 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.434388    9619 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.471978    9601 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.514112    9759 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.520194    9600 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.521058    9602 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.594733    9609 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.602458    9753 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.623340    9614 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.692986    9787 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.710991    9738 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.758265    9777 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.784660    9755 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.969632    9728 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662995.974014    9603 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.050251    9742 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.114738    9726 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.129208    9645 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.137690    9615 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.151132    9608 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.158579    9699 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.158579    9713 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.178412    9687 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.179585    9616 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.180275    9617 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.180914    9734 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.185465    9599 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.202410    9698 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.202389    9696 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.207286    9703 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.207287    9606 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.207286    9689 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.207440    9607 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.217866    9710 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.219272    9611 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.223729    9688 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.225688    9612 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.238424    9718 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.246136    9707 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.270886    9769 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.308485    9610 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.313645    9720 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.316979    9605 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.317455    9722 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.323694    9724 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.336300    9598 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.340886    9733 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.342551    9717 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.342557    9705 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.342549    9732 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.342635    9622 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.359537    9613 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.361818    9715 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.365413    9618 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.379179    9604 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.403411    9750 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.469386    9736 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# I0000 00:00:1656662996.469375    9778 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.487954    9747 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.509824    9745 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.531043    9789 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.538157    9767 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.546652    9749 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.555767    9773 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.558667    9763 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.580243    9772 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.609219    9758 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.722323    9796 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.724915    9780 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.728156    9791 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.734175    9785 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.751117    9762 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.864840    9793 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.895477    9783 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662996.942266    9765 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662997.023066    9788 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# WARNING: Logging before InitGoogle() is written to STDERR
# I0000 00:00:1656662997.025860    9799 tpu_initializer_helper.cc:165] libtpu.so already in use by another process probably owned by another user. Run "$ sudo lsof -w /dev/accel0" to figure out which process is using the TPU. Not attempting to load libtpu.so in this process.
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021333.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022386.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023988.txt
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023213.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022340.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-202101281b.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022870.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021024638.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022478.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022591.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021736.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023451.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022957.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023735.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022053.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022605.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022106.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023418.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023667.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022426.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012622.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012700.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023142.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012616.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012506.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021016914.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023162.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023020.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022310.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012613.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021014840.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023302.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012702.txt
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023761.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022967.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022852.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022678.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021957.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021014529.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021645.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022694.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021013086.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023014.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021020338.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023741.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021896.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021013704.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012525.txt
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022805.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021019376.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022698.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021905.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021020867.txt
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021024532.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021345.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022713.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022489.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021308.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023507.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023483.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023975.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021016853.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023842.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012615.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021437.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012520.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021016902.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022996.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012513.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023945.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021009337.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021707.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021020110.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021022838.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012515.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012716.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021023008.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021012514.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021021861.txt
# INFO:tensorflow:*** Reading from input files ***
# INFO:tensorflow:  /home/lj/WuDaoCorpus2.0_small_20G_text/part-2021015155.txt
# 80it [00:19, 65.57it/s]
